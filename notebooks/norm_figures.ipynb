# %%
import json
from pathlib import Path
from pprint import pprint
import numpy as np

from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['text.usetex'] = True
plt.rc('text.latex', preamble=r'\usepackage{amsmath} \usepackage{bm}')
# %config InlineBackend.figure_formats = ['svg']
PROJECT_ROOT = Path('..').resolve()

# %%
def set_centered_ylim(ax, y_data, margin=10):
    avg = sum(y_data) / len(y_data)
    # ymin = avg - avg
    # ymax = avg + avg
    ax.set_ylim(0, max(y_data))
    return avg
label_fontsize = 34
tick_fontsize = 30
cbar_fontsize = 30

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Glove

# %%
model_name = 'average_word_embeddings_glove.840B.300d' 
topk = 750
result_path = PROJECT_ROOT / f'results/{model_name}/norm_experiments/{str(topk)}/results.json'
with open(result_path, 'r') as f:
    result = json.load(f)

prob = np.array(result['prob'])
assert np.allclose(prob.sum() ,1)
logp = -np.log(prob)

norm = np.array(result['norm'])
uniform_centered_norm = np.array(result['uniform_PCA_centered_norm'])
uniform_whitened_norm = np.array(result['uniform_PCA_whitened_norm'])
zipfian_centered_norm = np.array(result['zipfian_PCA_centered_norm'])
zipfian_whitened_norm = np.array(result['zipfian_PCA_whitened_norm'])

data = {
    'Uniform Whitened': uniform_whitened_norm,
    'Uniform Centered': uniform_centered_norm,
    'Pre-trained GloVe': norm,
    'Zipfian Centered': zipfian_centered_norm,
    'Zipfian Whitened': zipfian_whitened_norm,
}

# Create subplots
fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharex=True)
alpha = 0.5
for i, (name, y_data) in enumerate(data.items()):
    x_data = logp
    axes[i].scatter(x_data, y_data,alpha=0.8,edgecolor='blue', facecolor='none')
    axes[i].set_title(name, fontsize=label_fontsize)
    axes[i].tick_params(axis='both', which='major', labelsize=tick_fontsize)
    _ = set_centered_ylim(axes[i], y_data)
# Adjust layout
plt.tight_layout()
# set title on top of the figure
print(f'Norm vs -log(p) for top {topk} words in {model_name}')
# Show plot
fig.text(0.5, -0.05, r'$-\log{p(w)}$', ha='center', va='center',fontsize=label_fontsize+5)
fig.text(-0.005, 0.5, r"${\lVert \bm{w} \rVert}_2$", ha='center', va='center', rotation='vertical',fontsize=label_fontsize+5)
plt.savefig('figs/norm_glove_default_750.pdf',bbox_inches='tight')
plt.show()
# Out:
# Norm vs -log(p) for top 750 words in average_word_embeddings_glove.840B.300d

# %%
prob = np.array(result['prob'])
assert np.allclose(prob.sum() ,1)
logp = -np.log(prob)

norm = np.array(result['norm'])
uniform_centered_norm_pca = np.array(result['uniform_PCA_centered_norm'])
uniform_whitened_norm_pca = np.array(result['uniform_PCA_whitened_norm'])
zipfian_centered_norm_pca = np.array(result['zipfian_PCA_centered_norm'])
zipfian_whitened_norm_pca = np.array(result['zipfian_PCA_whitened_norm'])
uniform_whitened_norm_zca = np.array(result['uniform_ZCA_whitened_norm'])
zipfian_whitened_norm_zca = np.array(result['zipfian_ZCA_whitened_norm'])
uniform_whitened_norm_chol = np.array(result['uniform_Cholesky_whitened_norm'])
zipfian_whitened_norm_chol = np.array(result['zipfian_Cholesky_whitened_norm'])

data = {
    'Pre-trained GloVe': norm,
    'Uniform Centered PCA': uniform_centered_norm_pca,
    'Zipfian Centered PCA': zipfian_centered_norm_pca,
    'Uniform Whitened PCA': uniform_whitened_norm_pca,
    'Uniform Whitened ZCA': uniform_whitened_norm_zca,
    'Uniform Whitened Chol': uniform_whitened_norm_chol,
    'Zipfian Whitened PCA': zipfian_whitened_norm_pca,
    'Zipfian Whitened ZCA': zipfian_whitened_norm_zca,
    'Zipfian Whitened Chol': zipfian_whitened_norm_chol,
}

# Create subplots
fig, axes = plt.subplots(3, 3, figsize=(30, 15), sharex=True)
alpha = 0.5
j, i = 0, 0
for _, (name, y_data) in enumerate(data.items()):
    x_data = logp
    axes[j, i].scatter(x_data, y_data,alpha=0.8,edgecolor='blue', facecolor='none')
    axes[j, i].set_title(name, fontsize=label_fontsize)
    axes[j, i].tick_params(axis='both', which='major', labelsize=tick_fontsize)
    _ = set_centered_ylim(axes[j, i], y_data)
    i += 1
    if i == 3:
        j += 1
        i -= 3
        
# Adjust layout
plt.tight_layout()
# set title on top of the figure
print(f'Norm vs -log(p) for top {topk} words in {model_name}')
# Show plot
fig.text(0.5, -0.05, r'$-\log{p(w)}$', ha='center', va='center',fontsize=label_fontsize+5)
fig.text(-0.005, 0.5, r"${\lVert \bm{w} \rVert}_2$", ha='center', va='center', rotation='vertical',fontsize=label_fontsize+5)
plt.savefig('figs/all_norm_glove.pdf',bbox_inches='tight')
plt.show()
# Out:
# Norm vs -log(p) for top 500 words in GoogleNews-vectors-negative300-torch

# %% [markdown]
# ### Word2Vec

# %%
model_name = 'GoogleNews-vectors-negative300-torch'

topk = 750
result_path = PROJECT_ROOT / f'results/{model_name}/norm_experiments/{str(topk)}/results.json'
with open(result_path, 'r') as f:
    result = json.load(f)

prob = np.array(result['prob'])
assert np.allclose(prob.sum() ,1)
logp = -np.log(prob)

norm = np.array(result['norm'])
uniform_centered_norm = np.array(result['uniform_PCA_centered_norm'])
uniform_whitened_norm = np.array(result['uniform_PCA_whitened_norm'])
zipfian_centered_norm = np.array(result['zipfian_PCA_centered_norm'])
zipfian_whitened_norm = np.array(result['zipfian_PCA_whitened_norm'])

data = {
    'Uniform Whitened': uniform_whitened_norm,
    'Uniform Centered': uniform_centered_norm,
    'Pre-trained GloVe': norm,
    'Zipfian Centered': zipfian_centered_norm,
    'Zipfian Whitened': zipfian_whitened_norm,
}

# Create subplots
fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharex=True)
alpha = 0.5
for i, (name, y_data) in enumerate(data.items()):
    x_data = logp
    axes[i].scatter(x_data, y_data,alpha=0.8,edgecolor='blue', facecolor='none')
    axes[i].set_title(name, fontsize=label_fontsize)
    axes[i].tick_params(axis='both', which='major', labelsize=tick_fontsize)
    _ = set_centered_ylim(axes[i], y_data)
# Adjust layout
plt.tight_layout()
# set title on top of the figure
print(f'Norm vs -log(p) for top {topk} words in {model_name}')
# Show plot
fig.text(0.5, -0.05, r'$-\log{p(w)}$', ha='center', va='center',fontsize=label_fontsize+5)
fig.text(-0.005, 0.5, r"${\lVert \bm{w} \rVert}_2$", ha='center', va='center', rotation='vertical',fontsize=label_fontsize+5)
plt.savefig('figs/norm_word2vec_default_750.pdf',bbox_inches='tight')
plt.show()
# Out:
# Norm vs -log(p) for top 750 words in GoogleNews-vectors-negative300-torch

# %%
prob = np.array(result['prob'])
assert np.allclose(prob.sum() ,1)
logp = -np.log(prob)

norm = np.array(result['norm'])
uniform_centered_norm_pca = np.array(result['uniform_PCA_centered_norm'])
uniform_whitened_norm_pca = np.array(result['uniform_PCA_whitened_norm'])
zipfian_centered_norm_pca = np.array(result['zipfian_PCA_centered_norm'])
zipfian_whitened_norm_pca = np.array(result['zipfian_PCA_whitened_norm'])
uniform_whitened_norm_zca = np.array(result['uniform_ZCA_whitened_norm'])
zipfian_whitened_norm_zca = np.array(result['zipfian_ZCA_whitened_norm'])
uniform_whitened_norm_chol = np.array(result['uniform_Cholesky_whitened_norm'])
zipfian_whitened_norm_chol = np.array(result['zipfian_Cholesky_whitened_norm'])

data = {
    'Pre-trained GloVe': norm,
    'Uniform Centered PCA': uniform_centered_norm_pca,
    'Zipfian Centered PCA': zipfian_centered_norm_pca,
    'Uniform Whitened PCA': uniform_whitened_norm_pca,
    'Uniform Whitened ZCA': uniform_whitened_norm_zca,
    'Uniform Whitened Chol': uniform_whitened_norm_chol,
    'Zipfian Whitened PCA': zipfian_whitened_norm_pca,
    'Zipfian Whitened ZCA': zipfian_whitened_norm_zca,
    'Zipfian Whitened Chol': zipfian_whitened_norm_chol,
}

# Create subplots
fig, axes = plt.subplots(3, 3, figsize=(30, 15), sharex=True)
alpha = 0.5
j, i = 0, 0
for _, (name, y_data) in enumerate(data.items()):
    x_data = logp
    axes[j, i].scatter(x_data, y_data,alpha=0.8,edgecolor='blue', facecolor='none')
    axes[j, i].set_title(name, fontsize=label_fontsize)
    axes[j, i].tick_params(axis='both', which='major', labelsize=tick_fontsize)
    _ = set_centered_ylim(axes[j, i], y_data)
    i += 1
    if i == 3:
        j += 1
        i -= 3
        
# Adjust layout
plt.tight_layout()
# set title on top of the figure
print(f'Norm vs -log(p) for top {topk} words in {model_name}')
# Show plot
fig.text(0.5, -0.05, r'$-\log{p(w)}$', ha='center', va='center',fontsize=label_fontsize+5)
fig.text(-0.005, 0.5, r"${\lVert \bm{w} \rVert}_2$", ha='center', va='center', rotation='vertical',fontsize=label_fontsize+5)
plt.savefig('figs/all_norm_word2vec.pdf',bbox_inches='tight')
plt.show()
# Out:
# Norm vs -log(p) for top 500 words in GoogleNews-vectors-negative300-torch

# %% [markdown]
# ### fasttext

# %%
model_name = 'fasttext-en-torch' 

topk = 750
result_path = PROJECT_ROOT / f'results/{model_name}/norm_experiments/{str(topk)}/results.json'
with open(result_path, 'r') as f:
    result = json.load(f)

prob = np.array(result['prob'])
assert np.allclose(prob.sum() ,1)
logp = -np.log(prob)

norm = np.array(result['norm'])
uniform_centered_norm = np.array(result['uniform_PCA_centered_norm'])
uniform_whitened_norm = np.array(result['uniform_PCA_whitened_norm'])
zipfian_centered_norm = np.array(result['zipfian_PCA_centered_norm'])
zipfian_whitened_norm = np.array(result['zipfian_PCA_whitened_norm'])

data = {
    'Uniform Whitened': uniform_whitened_norm,
    'Uniform Centered': uniform_centered_norm,
    'Pre-trained GloVe': norm,
    'Zipfian Centered': zipfian_centered_norm,
    'Zipfian Whitened': zipfian_whitened_norm,
}

# Create subplots
fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharex=True)
alpha = 0.5
for i, (name, y_data) in enumerate(data.items()):
    x_data = logp
    axes[i].scatter(x_data, y_data,alpha=0.8,edgecolor='blue', facecolor='none')
    axes[i].set_title(name, fontsize=label_fontsize)
    axes[i].tick_params(axis='both', which='major', labelsize=tick_fontsize)
    _ = set_centered_ylim(axes[i], y_data)
# Adjust layout
plt.tight_layout()
# set title on top of the figure
print(f'Norm vs -log(p) for top {topk} words in {model_name}')
# Show plot
fig.text(0.5, -0.05, r'$-\log{p(w)}$', ha='center', va='center',fontsize=label_fontsize+5)
fig.text(-0.005, 0.5, r"${\lVert \bm{w} \rVert}_2$", ha='center', va='center', rotation='vertical',fontsize=label_fontsize+5)
plt.savefig('figs/norm_fasttext_default_750.pdf',bbox_inches='tight')
plt.show()
# Out:
# Norm vs -log(p) for top 750 words in fasttext-en-torch

# %% [markdown]
# ### fasttext-subword

# %%
model_name = 'fasttext-en-subword-torch' 
topk = 750
result_path = PROJECT_ROOT / f'results/{model_name}/norm_experiments/{str(topk)}/results.json'
with open(result_path, 'r') as f:
    result = json.load(f)

prob = np.array(result['prob'])
assert np.allclose(prob.sum() ,1)
logp = -np.log(prob)

norm = np.array(result['norm'])
uniform_centered_norm = np.array(result['uniform_PCA_centered_norm'])
uniform_whitened_norm = np.array(result['uniform_PCA_whitened_norm'])
zipfian_centered_norm = np.array(result['zipfian_PCA_centered_norm'])
zipfian_whitened_norm = np.array(result['zipfian_PCA_whitened_norm'])

data = {
    'Uniform Whitened': uniform_whitened_norm,
    'Uniform Centered': uniform_centered_norm,
    'Pre-trained GloVe': norm,
    'Zipfian Centered': zipfian_centered_norm,
    'Zipfian Whitened': zipfian_whitened_norm,
}

# Create subplots
fig, axes = plt.subplots(1, 5, figsize=(25, 5), sharex=True)
alpha = 0.5
for i, (name, y_data) in enumerate(data.items()):
    x_data = logp
    axes[i].scatter(x_data, y_data,alpha=0.8,edgecolor='blue', facecolor='none')
    axes[i].set_title(name, fontsize=label_fontsize)
    axes[i].tick_params(axis='both', which='major', labelsize=tick_fontsize)
    _ = set_centered_ylim(axes[i], y_data)
# Adjust layout
plt.tight_layout()
# set title on top of the figure
print(f'Norm vs -log(p) for top {topk} words in {model_name}')
# Show plot
fig.text(0.5, -0.05, r'$-\log{p(w)}$', ha='center', va='center',fontsize=label_fontsize+5)
fig.text(-0.005, 0.5, r"${\lVert \bm{w} \rVert}_2$", ha='center', va='center', rotation='vertical',fontsize=label_fontsize+5)
plt.savefig('figs/norm_fasttext_subword_default_750.pdf',bbox_inches='tight')
plt.show()
# Out:
# Norm vs -log(p) for top 750 words in fasttext-en-subword-torch
